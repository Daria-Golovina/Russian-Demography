# %% [markdown]
# # <center>Постоянная миграция и эмиграция в 2011-2019</center>

# %% [markdown]
# ## <center>Содержание</center>

# %% [markdown]
# <br>**Введение**
# <br>**Импорт библиотек**
# <br>**Первичное знакомство с данными**
# <br>**Постоянная миграция 2011-2019**
# + Санкт-Петербург и Москва
# + Основные места постоянной миграции
#
# <br>**Эмиграция 2011-2019**
# + Предобработка данных
# + Основные источники эмиграции
# + Санкт-Петербург и Москва
# + Ленинградская и Московская области
#
# <br>**Выводы**

# %% [markdown]
# ## <center>Введение</center>

# %% [markdown]
# Исследование проводится по данным ИНИД (инфраструктура научно-исследовательских данных) "Демография в России: объединённые панельные данные за 1990-2019 годы": https://data-in.ru/data-catalog/datasets/164/
#
# Исследоваться будет в первую очередь Санкт-Петербург (в сравнении с Москвой) - связано это исключительно с личным любопытством исследователя :) И в первую очередь интересует его постоянная миграция в Санкт-Петербург, то есть переезды, и эмиграция в другие страны. Соответственно, здесь будут рассматриваться именно эти части датасета по миграции `data_migration` - поехали.

# %% [markdown]
# ## <center>Импорт библиотек</center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns

# %% [markdown]
# ## <center>Первичное знакомство с данными</center>

# %% [markdown]
# Считаем данные и посмотрим, с чем мы имеем дело:

# %%
data_migration = pd.read_csv('data_migration.csv', low_memory=False)
display(data_migration.head(20))
# Out:
#     id           object_name  object_oktmo  object_okato  year  \
# 0    1  Российская Федерация           NaN           NaN  2010
# 1    2  Российская Федерация           NaN           NaN  2011
# 2    3  Российская Федерация           NaN           NaN  2012
# 3    4  Российская Федерация           NaN           NaN  2013
# 4    5  Российская Федерация           NaN           NaN  2014
# 5    6  Российская Федерация           NaN           NaN  2015
# 6    7  Российская Федерация           NaN           NaN  2016
# 7    8  Российская Федерация           NaN           NaN  2017
# 8    9  Российская Федерация           NaN           NaN  2018
# 9   10  Российская Федерация           NaN           NaN  2019
# 10  11  Российская Федерация           NaN           NaN  1997
# 11  12  Российская Федерация           NaN           NaN  1998
# 12  13  Российская Федерация           NaN           NaN  2000
# 13  14  Российская Федерация           NaN           NaN  2001
# 14  15  Российская Федерация           NaN           NaN  2002
# 15  16  Российская Федерация           NaN           NaN  2003
# 16  17  Российская Федерация           NaN           NaN  2004
# 17  18  Российская Федерация           NaN           NaN  2005
# 18  19  Российская Федерация           NaN           NaN  2006
# 19  20  Российская Федерация           NaN           NaN  2007
#
#                               indicator_name indicator_unit  \
# 0   Международная миграция — число прибывших        человек
# 1   Международная миграция — число прибывших        человек
# 2   Международная миграция — число прибывших        человек
# 3   Международная миграция — число прибывших        человек
# 4   Международная миграция — число прибывших        человек
# 5   Международная миграция — число прибывших        человек
# 6   Международная миграция — число прибывших        человек
# 7   Международная миграция — число прибывших        человек
# 8   Международная миграция — число прибывших        человек
# 9   Международная миграция — число прибывших        человек
# 10  Международная миграция — число прибывших        человек
# 11  Международная миграция — число прибывших        человек
# 12  Международная миграция — число прибывших        человек
# 13  Международная миграция — число прибывших        человек
# 14  Международная миграция — число прибывших        человек
# 15  Международная миграция — число прибывших        человек
# 16  Международная миграция — число прибывших        человек
# 17  Международная миграция — число прибывших        человек
# 18  Международная миграция — число прибывших        человек
# 19  Международная миграция — число прибывших        человек
#
#                          area_type age_group  sex migration_direction  \
# 0   городское и сельское население       NaN  NaN                 NaN
# 1   городское и сельское население       NaN  NaN                 NaN
# 2   городское и сельское население       NaN  NaN                 NaN
# 3   городское и сельское население       NaN  NaN                 NaN
# 4   городское и сельское население       NaN  NaN                 NaN
# 5   городское и сельское население       NaN  NaN                 NaN
# 6   городское и сельское население       NaN  NaN                 NaN
# 7   городское и сельское население       NaN  NaN                 NaN
# 8   городское и сельское население       NaN  NaN                 NaN
# 9   городское и сельское население       NaN  NaN                 NaN
# 10  городское и сельское население       NaN  NaN                 NaN
# 11  городское и сельское население       NaN  NaN                 NaN
# 12  городское и сельское население       NaN  NaN                 NaN
# 13  городское и сельское население       NaN  NaN                 NaN
# 14  городское и сельское население       NaN  NaN                 NaN
# 15  городское и сельское население       NaN  NaN                 NaN
# 16  городское и сельское население       NaN  NaN                 NaN
# 17  городское и сельское население       NaN  NaN                 NaN
# 18  городское и сельское население       NaN  NaN                 NaN
# 19  городское и сельское население       NaN  NaN                 NaN
#
#       country region territory_type registration_type citizenship  \
# 0     Абхазия    NaN            NaN               NaN         NaN
# 1     Абхазия    NaN            NaN               NaN         NaN
# 2     Абхазия    NaN            NaN               NaN         NaN
# 3     Абхазия    NaN            NaN               NaN         NaN
# 4     Абхазия    NaN            NaN               NaN         NaN
# 5     Абхазия    NaN            NaN               NaN         NaN
# 6     Абхазия    NaN            NaN               NaN         NaN
# 7     Абхазия    NaN            NaN               NaN         NaN
# 8     Абхазия    NaN            NaN               NaN         NaN
# 9     Абхазия    NaN            NaN               NaN         NaN
# 10  Австралия    NaN            NaN               NaN         NaN
# 11  Австралия    NaN            NaN               NaN         NaN
# 12  Австралия    NaN            NaN               NaN         NaN
# 13  Австралия    NaN            NaN               NaN         NaN
# 14  Австралия    NaN            NaN               NaN         NaN
# 15  Австралия    NaN            NaN               NaN         NaN
# 16  Австралия    NaN            NaN               NaN         NaN
# 17  Австралия    NaN            NaN               NaN         NaN
# 18  Австралия    NaN            NaN               NaN         NaN
# 19  Австралия    NaN            NaN               NaN         NaN
#
#     indicator_value  original_accuracy               methodology  notes
# 0             814.0                0.0  migration_1, migration_5    NaN
# 1            2429.0                0.0  migration_1, migration_5    NaN
# 2            2487.0                0.0  migration_1, migration_5    NaN
# 3            3001.0                0.0  migration_1, migration_5    NaN
# 4            2337.0                0.0  migration_1, migration_5    NaN
# 5            2267.0                0.0  migration_1, migration_5    NaN
# 6            2261.0                0.0  migration_1, migration_5    NaN
# 7            2357.0                0.0  migration_1, migration_5    NaN
# 8            1975.0                0.0  migration_1, migration_5    NaN
# 9            1429.0                0.0  migration_1, migration_6    NaN
# 10             57.0                0.0  migration_1, migration_4    NaN
# 11             52.0                0.0  migration_1, migration_4    NaN
# 12             27.0                0.0  migration_1, migration_4    NaN
# 13             25.0                0.0  migration_1, migration_4    NaN
# 14             22.0                0.0  migration_1, migration_4    NaN
# 15             30.0                0.0  migration_1, migration_4    NaN
# 16             42.0                0.0  migration_1, migration_4    NaN
# 17             30.0                0.0  migration_1, migration_4    NaN
# 18             28.0                0.0  migration_1, migration_4    NaN
# 19             38.0                0.0  migration_1, migration_5    NaN

# %%
display(data_migration.tail(10))
# Out:
#               id           object_name  object_oktmo  object_okato  year  \
# 2527848  2527849  Российская Федерация           NaN           NaN  2019
# 2527849  2527850  Российская Федерация           NaN           NaN  2011
# 2527850  2527851  Российская Федерация           NaN           NaN  2012
# 2527851  2527852  Российская Федерация           NaN           NaN  2013
# 2527852  2527853  Российская Федерация           NaN           NaN  2014
# 2527853  2527854  Российская Федерация           NaN           NaN  2015
# 2527854  2527855  Российская Федерация           NaN           NaN  2016
# 2527855  2527856  Российская Федерация           NaN           NaN  2017
# 2527856  2527857  Российская Федерация           NaN           NaN  2018
# 2527857  2527858  Российская Федерация           NaN           NaN  2019
#
#                                             indicator_name indicator_unit  \
# 2527848  Миграция по видам и срокам регистрации — мигра...        человек
# 2527849  Миграция по видам и срокам регистрации — мигра...        человек
# 2527850  Миграция по видам и срокам регистрации — мигра...        человек
# 2527851  Миграция по видам и срокам регистрации — мигра...        человек
# 2527852  Миграция по видам и срокам регистрации — мигра...        человек
# 2527853  Миграция по видам и срокам регистрации — мигра...        человек
# 2527854  Миграция по видам и срокам регистрации — мигра...        человек
# 2527855  Миграция по видам и срокам регистрации — мигра...        человек
# 2527856  Миграция по видам и срокам регистрации — мигра...        человек
# 2527857  Миграция по видам и срокам регистрации — мигра...        человек
#
#                               area_type age_group  sex migration_direction  \
# 2527848  городское и сельское население       NaN  NaN                 NaN
# 2527849  городское и сельское население       NaN  NaN                 NaN
# 2527850  городское и сельское население       NaN  NaN                 NaN
# 2527851  городское и сельское население       NaN  NaN                 NaN
# 2527852  городское и сельское население       NaN  NaN                 NaN
# 2527853  городское и сельское население       NaN  NaN                 NaN
# 2527854  городское и сельское население       NaN  NaN                 NaN
# 2527855  городское и сельское население       NaN  NaN                 NaN
# 2527856  городское и сельское население       NaN  NaN                 NaN
# 2527857  городское и сельское население       NaN  NaN                 NaN
#
#         country               region territory_type  \
# 2527848     NaN  Ярославская область            NaN
# 2527849     NaN  Ярославская область            NaN
# 2527850     NaN  Ярославская область            NaN
# 2527851     NaN  Ярославская область            NaN
# 2527852     NaN  Ярославская область            NaN
# 2527853     NaN  Ярославская область            NaN
# 2527854     NaN  Ярославская область            NaN
# 2527855     NaN  Ярославская область            NaN
# 2527856     NaN  Ярославская область            NaN
# 2527857     NaN  Ярославская область            NaN
#
#                                          registration_type citizenship  \
# 2527848     передвижения к месту пребывания на срок 4 года         NaN
# 2527849  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527850  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527851  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527852  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527853  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527854  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527855  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527856  передвижения к месту пребывания на срок 5 лет ...         NaN
# 2527857  передвижения к месту пребывания на срок 5 лет ...         NaN
#
#          indicator_value  original_accuracy  methodology  notes
# 2527848           -171.0                0.0  migration_3    NaN
# 2527849           -933.0                0.0  migration_3    NaN
# 2527850          -1059.0                0.0  migration_3    NaN
# 2527851          -1213.0                0.0  migration_3    NaN
# 2527852           -949.0                0.0  migration_3    NaN
# 2527853          -1251.0                0.0  migration_3    NaN
# 2527854          -1328.0                0.0  migration_3    NaN
# 2527855          -1095.0                0.0  migration_3    NaN
# 2527856          -1038.0                0.0  migration_3    NaN
# 2527857           -821.0                0.0  migration_3    NaN

# %%
print(data_migration.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2527858 entries, 0 to 2527857
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   id                   int64
#  1   object_name          object
#  2   object_oktmo         float64
#  3   object_okato         float64
#  4   year                 int64
#  5   indicator_name       object
#  6   indicator_unit       object
#  7   area_type            object
#  8   age_group            object
#  9   sex                  object
#  10  migration_direction  object
#  11  country              object
#  12  region               object
#  13  territory_type       object
#  14  registration_type    object
#  15  citizenship          object
#  16  indicator_value      float64
#  17  original_accuracy    float64
#  18  methodology          object
#  19  notes                float64
# dtypes: float64(5), int64(2), object(13)
# memory usage: 385.7+ MB
# None

# %% [markdown]
# Выведем список регионов:

# %%
print(data_migration['region'].unique())
# Out:
# [nan 'Агинский Бурятский автономный округ' 'Алтайский край'
#  'Амурская область' 'Архангельская область'
#  'Архангельская область без Ненецкого автономного округа'
#  'Астраханская область' 'Белгородская область' 'Брянская область'
#  'Владимирская область' 'Волгоградская область' 'Вологодская область'
#  'Воронежская область' 'Дальневосточный федеральный округ'
#  'Еврейская автономная область' 'Забайкальский край' 'Ивановская область'
#  'Иркутская область' 'Кабардино-Балкарская Республика'
#  'Калининградская область' 'Калужская область' 'Камчатская область'
#  'Камчатский край' 'Карачаево-Черкесская Республика'
#  'Кемеровская область – Кузбасс' 'Кировская область'
#  'Коми-Пермяцкий автономный округ' 'Корякский автономный округ'
#  'Костромская область' 'Краснодарский край' 'Красноярский край'
#  'Крымский федеральный округ' 'Курганская область' 'Курская область'
#  'Ленинградская область' 'Липецкая область' 'Магаданская область' 'Москва'
#  'Московская область' 'Мурманская область' 'Ненецкий автономный округ'
#  'Нижегородская область' 'Новгородская область' 'Новосибирская область'
#  'Омская область' 'Оренбургская область' 'Орловская область'
#  'Пензенская область' 'Пермская область' 'Пермский край'
#  'Приволжский федеральный округ' 'Приморский край' 'Псковская область'
#  'Республика Адыгея (Адыгея)' 'Республика Алтай' 'Республика Башкортостан'
#  'Республика Бурятия' 'Республика Дагестан' 'Республика Ингушетия'
#  'Республика Калмыкия' 'Республика Карелия' 'Республика Коми'
#  'Республика Крым' 'Республика Марий Эл' 'Республика Мордовия'
#  'Республика Саха (Якутия)' 'Республика Северная Осетия – Алания'
#  'Республика Татарстан (Татарстан)' 'Республика Тыва' 'Республика Хакасия'
#  'Российская Федерация' 'Ростовская область' 'Рязанская область'
#  'Самарская область' 'Санкт-Петербург' 'Саратовская область'
#  'Сахалинская область' 'Свердловская область' 'Севастополь'
#  'Северо-Западный федеральный округ' 'Северо-Кавказский федеральный округ'
#  'Сибирский федеральный округ' 'Смоленская область' 'Ставропольский край'
#  'Таймырский (Долгано-Ненецкий) автономный округ' 'Тамбовская область'
#  'Тверская область' 'Томская область' 'Тульская область'
#  'Тюменская область' 'Тюменская область без автономий'
#  'Удмуртская Республика' 'Ульяновская область'
#  'Уральский федеральный округ' 'Усть-Ордынский Бурятский автономный округ'
#  'Хабаровский край' 'Ханты-Мансийский автономный округ – Югра'
#  'Центральный федеральный округ' 'Челябинская область'
#  'Чеченская Республика' 'Читинская область'
#  'Чувашская Республика – Чувашия' 'Чукотский автономный округ'
#  'Эвенкийский автономный округ' 'Южный федеральный округ'
#  'Ямало-Ненецкий автономный округ' 'Ярославская область']

# %% [markdown]
# Запомним, что в сете есть подсчёты по федеральным округам, а также `Российская Федерация`, которая представляет собой общую сумму - при ранжировании регионов эти записи нужно будет убрать. Начнём рассматривать данные более подробно:

# %% [markdown]
# ## <center>Постоянная миграция 2011-2019</center>

# %% [markdown]
# ### <center>Cанкт-Петербург и Москва<center>

# %% [markdown]
# Временная миграция (или же вся миграция, включая временную) может послужить темой отдельного исследования - если же мы хотим попробовать оценить постоянную миграцию, то есть "переезд навсегда", имеет смысл рассмотреть графу `прибыли и зарегистрированы в новом месте жительства`. Начнём с Санкт-Петербурга - выделим данные, относящиеся к нему:

# %%
data_spb = data_migration[data_migration['region'] == 'Санкт-Петербург'].copy()
data_spb_in = data_spb[data_spb['registration_type'] == 'прибыли и зарегистрированы в новом месте жительства']
display(data_spb_in)
# Out:
#               id           object_name  object_oktmo  object_okato  year  \
# 2496677  2496678  Российская Федерация           NaN           NaN  2011
# 2496678  2496679  Российская Федерация           NaN           NaN  2012
# 2496679  2496680  Российская Федерация           NaN           NaN  2013
# 2496680  2496681  Российская Федерация           NaN           NaN  2014
# 2496681  2496682  Российская Федерация           NaN           NaN  2015
# 2496682  2496683  Российская Федерация           NaN           NaN  2016
# 2496683  2496684  Российская Федерация           NaN           NaN  2017
# 2496684  2496685  Российская Федерация           NaN           NaN  2018
# 2496685  2496686  Российская Федерация           NaN           NaN  2019
#
#                                             indicator_name indicator_unit  \
# 2496677  Миграция по видам и срокам регистрации — число...        человек
# 2496678  Миграция по видам и срокам регистрации — число...        человек
# 2496679  Миграция по видам и срокам регистрации — число...        человек
# 2496680  Миграция по видам и срокам регистрации — число...        человек
# 2496681  Миграция по видам и срокам регистрации — число...        человек
# 2496682  Миграция по видам и срокам регистрации — число...        человек
# 2496683  Миграция по видам и срокам регистрации — число...        человек
# 2496684  Миграция по видам и срокам регистрации — число...        человек
# 2496685  Миграция по видам и срокам регистрации — число...        человек
#
#                               area_type age_group  sex migration_direction  \
# 2496677  городское и сельское население       NaN  NaN                 NaN
# 2496678  городское и сельское население       NaN  NaN                 NaN
# 2496679  городское и сельское население       NaN  NaN                 NaN
# 2496680  городское и сельское население       NaN  NaN                 NaN
# 2496681  городское и сельское население       NaN  NaN                 NaN
# 2496682  городское и сельское население       NaN  NaN                 NaN
# 2496683  городское и сельское население       NaN  NaN                 NaN
# 2496684  городское и сельское население       NaN  NaN                 NaN
# 2496685  городское и сельское население       NaN  NaN                 NaN
#
#         country           region territory_type  \
# 2496677     NaN  Санкт-Петербург            NaN
# 2496678     NaN  Санкт-Петербург            NaN
# 2496679     NaN  Санкт-Петербург            NaN
# 2496680     NaN  Санкт-Петербург            NaN
# 2496681     NaN  Санкт-Петербург            NaN
# 2496682     NaN  Санкт-Петербург            NaN
# 2496683     NaN  Санкт-Петербург            NaN
# 2496684     NaN  Санкт-Петербург            NaN
# 2496685     NaN  Санкт-Петербург            NaN
#
#                                          registration_type citizenship  \
# 2496677  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496678  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496679  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496680  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496681  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496682  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496683  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496684  прибыли и зарегистрированы в новом месте жител...         NaN
# 2496685  прибыли и зарегистрированы в новом месте жител...         NaN
#
#          indicator_value  original_accuracy               methodology  notes
# 2496677          49690.0                0.0  migration_1, migration_5    NaN
# 2496678          59634.0                0.0  migration_1, migration_5    NaN
# 2496679          66816.0                0.0  migration_1, migration_5    NaN
# 2496680          66816.0                0.0  migration_1, migration_5    NaN
# 2496681          73439.0                0.0  migration_1, migration_5    NaN
# 2496682          76178.0                0.0  migration_1, migration_5    NaN
# 2496683          83518.0                0.0  migration_1, migration_5    NaN
# 2496684          81309.0                0.0  migration_1, migration_5    NaN
# 2496685          76631.0                0.0  migration_1, migration_6    NaN

# %% [markdown]
# Записи похожи на то, что нам нужно - пока что оставим их в таком виде и попробуем выделить всё то же самое для Москвы:

# %%
data_moscow = data_migration[data_migration['region'] == 'Москва'].copy()
data_moscow_in = data_moscow[data_moscow['registration_type'] == 'прибыли и зарегистрированы в новом месте жительства']
display(data_moscow_in)
# Out:
#               id           object_name  object_oktmo  object_okato  year  \
# 2493437  2493438  Российская Федерация           NaN           NaN  2011
# 2493438  2493439  Российская Федерация           NaN           NaN  2012
# 2493439  2493440  Российская Федерация           NaN           NaN  2013
# 2493440  2493441  Российская Федерация           NaN           NaN  2014
# 2493441  2493442  Российская Федерация           NaN           NaN  2015
# 2493442  2493443  Российская Федерация           NaN           NaN  2016
# 2493443  2493444  Российская Федерация           NaN           NaN  2017
# 2493444  2493445  Российская Федерация           NaN           NaN  2018
# 2493445  2493446  Российская Федерация           NaN           NaN  2019
#
#                                             indicator_name indicator_unit  \
# 2493437  Миграция по видам и срокам регистрации — число...        человек
# 2493438  Миграция по видам и срокам регистрации — число...        человек
# 2493439  Миграция по видам и срокам регистрации — число...        человек
# 2493440  Миграция по видам и срокам регистрации — число...        человек
# 2493441  Миграция по видам и срокам регистрации — число...        человек
# 2493442  Миграция по видам и срокам регистрации — число...        человек
# 2493443  Миграция по видам и срокам регистрации — число...        человек
# 2493444  Миграция по видам и срокам регистрации — число...        человек
# 2493445  Миграция по видам и срокам регистрации — число...        человек
#
#                               area_type age_group  sex migration_direction  \
# 2493437  городское и сельское население       NaN  NaN                 NaN
# 2493438  городское и сельское население       NaN  NaN                 NaN
# 2493439  городское и сельское население       NaN  NaN                 NaN
# 2493440  городское и сельское население       NaN  NaN                 NaN
# 2493441  городское и сельское население       NaN  NaN                 NaN
# 2493442  городское и сельское население       NaN  NaN                 NaN
# 2493443  городское и сельское население       NaN  NaN                 NaN
# 2493444  городское и сельское население       NaN  NaN                 NaN
# 2493445  городское и сельское население       NaN  NaN                 NaN
#
#         country  region territory_type  \
# 2493437     NaN  Москва            NaN
# 2493438     NaN  Москва            NaN
# 2493439     NaN  Москва            NaN
# 2493440     NaN  Москва            NaN
# 2493441     NaN  Москва            NaN
# 2493442     NaN  Москва            NaN
# 2493443     NaN  Москва            NaN
# 2493444     NaN  Москва            NaN
# 2493445     NaN  Москва            NaN
#
#                                          registration_type citizenship  \
# 2493437  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493438  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493439  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493440  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493441  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493442  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493443  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493444  прибыли и зарегистрированы в новом месте жител...         NaN
# 2493445  прибыли и зарегистрированы в новом месте жител...         NaN
#
#          indicator_value  original_accuracy               methodology  notes
# 2493437          39981.0                0.0  migration_1, migration_5    NaN
# 2493438          54877.0                0.0  migration_1, migration_5    NaN
# 2493439          47413.0                0.0  migration_1, migration_5    NaN
# 2493440          47413.0                0.0  migration_1, migration_5    NaN
# 2493441          47083.0                0.0  migration_1, migration_5    NaN
# 2493442          44153.0                0.0  migration_1, migration_5    NaN
# 2493443          44861.0                0.0  migration_1, migration_5    NaN
# 2493444          50367.0                0.0  migration_1, migration_5    NaN
# 2493445          43104.0                0.0  migration_1, migration_6    NaN

# %% [markdown]
# Получилось - вырежем всё лишнее и построим график переехавших по годам:

# %%
data_spb_graph = data_spb_in[['year', 'indicator_value']].reset_index(drop=True)
data_spb_graph['indicator_value'] = data_spb_graph['indicator_value'].astype('int64')
data_moscow_graph = data_moscow_in[['year', 'indicator_value']].reset_index(drop=True)
data_moscow_graph['indicator_value'] = data_moscow_graph['indicator_value'].astype('int64')

print('Санкт-Петербург:')
display(data_spb_graph)
print('Москва:')
display(data_moscow_graph)

plt.figure(figsize=(14, 8))
plt.plot(data_spb_in['year'], data_spb_in['indicator_value'], color='red', marker='o', label='СПб')
plt.plot(data_moscow_in['year'], data_moscow_in['indicator_value'], color='blue', marker='o', label='Москва')
plt.title('Постоянная миграция', fontsize=18)
plt.xlabel('год', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('зарегистрированы в новом месте жительства', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(loc='center right', fontsize=16)
plt.show()
# Out:
# Санкт-Петербург:
#    year  indicator_value
# 0  2011            49690
# 1  2012            59634
# 2  2013            66816
# 3  2014            66816
# 4  2015            73439
# 5  2016            76178
# 6  2017            83518
# 7  2018            81309
# 8  2019            76631
# Москва:
#    year  indicator_value
# 0  2011            39981
# 1  2012            54877
# 2  2013            47413
# 3  2014            47413
# 4  2015            47083
# 5  2016            44153
# 6  2017            44861
# 7  2018            50367
# 8  2019            43104

# %% [markdown]
# Признаюсь, для меня результат оказался неожиданным: я полагала, что в Москву люди стремятся сильнее, чем в Санкт-Петербург, однако всё наоборот: в Санкт-Петербург переселяются заметно больше людей. Рискну предположить, что связано это с ценами на жильё: в Санкт-Петербурге они более доступны.
#
# Крайне же сильное недоумение вызывают одинаковые числа для 2013 и 2014 года **и** по Москве, **и** по Санкт-Петербургу - вероятность подобного совпадения, прямо скажем, мала. Вывод этих записей:

# %%
#для запроса
data_what = data_migration[['id', 'year', 'region', 'indicator_name', 'area_type', 
                            'registration_type', 'indicator_value']].copy()
display(data_what.loc[[2496679, 2496680, 2493439, 2493440]])
# Out:
#               id  year           region  \
# 2496679  2496680  2013  Санкт-Петербург
# 2496680  2496681  2014  Санкт-Петербург
# 2493439  2493440  2013           Москва
# 2493440  2493441  2014           Москва
#
#                                             indicator_name  \
# 2496679  Миграция по видам и срокам регистрации — число...
# 2496680  Миграция по видам и срокам регистрации — число...
# 2493439  Миграция по видам и срокам регистрации — число...
# 2493440  Миграция по видам и срокам регистрации — число...
#
#                               area_type  \
# 2496679  городское и сельское население
# 2496680  городское и сельское население
# 2493439  городское и сельское население
# 2493440  городское и сельское население
#
#                                          registration_type  indicator_value
# 2496679  прибыли и зарегистрированы в новом месте жител...          66816.0
# 2496680  прибыли и зарегистрированы в новом месте жител...          66816.0
# 2493439  прибыли и зарегистрированы в новом месте жител...          47413.0
# 2493440  прибыли и зарегистрированы в новом месте жител...          47413.0

# %% [markdown]
# Запрос в ИНИД был отправлен - данные уточняются у Росстата.

# %% [markdown]
# ### <center>Основные места постоянной миграции</center>

# %% [markdown]
# Посмотрим, куда люди в основном переезжают - выделим нужную графу и проверим, есть ли пропуски в нужных нам `indicator_value`:

# %%
data_top_in = data_migration[(data_migration['registration_type'] == 'прибыли и зарегистрированы в новом месте жительства') & 
                            (data_migration['year'] >= 2011)].copy()
print(data_top_in.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1425 entries, 2485000 to 2499165
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1425 non-null   int64
#  1   object_name          1425 non-null   object
#  2   object_oktmo         0 non-null      float64
#  3   object_okato         0 non-null      float64
#  4   year                 1425 non-null   int64
#  5   indicator_name       1425 non-null   object
#  6   indicator_unit       1425 non-null   object
#  7   area_type            1425 non-null   object
#  8   age_group            0 non-null      object
#  9   sex                  0 non-null      object
#  10  migration_direction  0 non-null      object
#  11  country              564 non-null    object
#  12  region               861 non-null    object
#  13  territory_type       0 non-null      object
#  14  registration_type    1425 non-null   object
#  15  citizenship          192 non-null    object
#  16  indicator_value      1425 non-null   float64
#  17  original_accuracy    1425 non-null   float64
#  18  methodology          1425 non-null   object
#  19  notes                0 non-null      float64
# dtypes: float64(5), int64(2), object(13)
# memory usage: 233.8+ KB
# None

# %% [markdown]
# Все `indicator_value` на месте - можно собирать значения в таблицу. Также вспомним про федеральные округа и общее значение `Российская Федерация` и уберём их:

# %%
#сбор в таблицу
top_in = pd.pivot_table(data_top_in, index='region', values='indicator_value', aggfunc='sum').sort_values(
    by='indicator_value', ascending=False)
top_in['indicator_value'] = top_in['indicator_value'].astype('int64')

#убираем фед. округа и общую сумму
top_in = top_in[(top_in.index.str.contains('федеральный округ') == False) & 
                      (top_in.index.str.contains('Федерация') == False)]

#Выводим топ-10
display(top_in.head(10))
# Out:
#                                   indicator_value
# region
# Московская область                         961704
# Республика Башкортостан                    697546
# Тюменская область                          654370
# Санкт-Петербург                            634031
# Краснодарский край                         564404
# Ростовская область                         492028
# Республика Татарстан (Татарстан)           489523
# Красноярский край                          463524
# Свердловская область                       448925
# Москва                                     419252

# %% [markdown]
# Построим график - для его вывода напишем функцию, потому что подобный график мы ещё не раз выведем в дальнейшем:

# %%
def tops_plot(series, N, name):
    series_plot = series.head(N)
    plt.figure(figsize=(12, 12))
    plt.barh(series_plot.index, series_plot['indicator_value'])
    plt.title(name, fontsize=18)
    plt.xticks(fontsize=14)
    plt.ticklabel_format(style='plain', axis='x')
    plt.yticks(fontsize=14)
    plt.grid(True)
    plt.gca().invert_yaxis()
    plt.show()

# %%
tops_plot(top_in, 10, 'Переселившиеся')

# %% [markdown]
# В топе-10 мест постоянной миграции Москва занимает почётное последнее место; а вот Московская область - первое, за девять лет туда переехали почти миллион человек. В принципе ожидаемо - неожиданными для меня вторая и третья позиции, то есть Башкортостан и Тюменская область. Санкт-Петербург в этом списке занимает почётное четвёртое место.

# %% [markdown]
# ## <center>Эмиграция 2011-2019</center>

# %% [markdown]
# ### <center>Предобработка данных</center>

# %% [markdown]
# Посмотрим на типы миграции, которые у нас есть:

# %%
print(data_migration['indicator_name'].unique())
# Out:
# ['Международная миграция — число прибывших'
#  'Международная миграция — число выбывших'
#  'Международная миграция — миграционный прирост'
#  'Миграция с зарубежными странами — число прибывших'
#  'Миграция с зарубежными странами — число выбывших'
#  'Миграция с зарубежными странами — миграционный прирост'
#  'Миграция со странами СНГ и Балтии — число прибывших'
#  'Миграция со странами СНГ и Балтии — число выбывших'
#  'Миграция со странами СНГ и Балтии — миграционный прирост'
#  'Миграция по полу и возрасту — число прибывших'
#  'Миграция по полу и возрасту — число выбывших'
#  'Миграция по полу и возрасту — миграционный прирост'
#  'Общие итоги миграции по субъектам — число прибывших'
#  'Общие итоги миграции по субъектам — число выбывших'
#  'Общие итоги миграции по субъектам — миграционный прирост'
#  'Миграция с зарубежными странами по субъектам — число прибывших'
#  'Миграция с зарубежными странами по субъектам — число выбывших'
#  'Миграция с зарубежными странами по субъектам — миграционный прирост'
#  'Миграция со странами СНГ и Балтии по субъектам — число прибывших'
#  'Миграция со странами СНГ и Балтии по субъектам — число выбывших'
#  'Миграция со странами СНГ и Балтии по субъектам — миграционный прирост'
#  'Миграция по полу и возрасту по субъектам — число прибывших'
#  'Миграция по полу и возрасту по субъектам — число выбывших'
#  'Миграция по полу и возрасту по субъектам — миграционный прирост'
#  'Коэффициент миграционного прироста по субъектам'
#  'Общие итоги миграции по городам — число прибывших'
#  'Общие итоги миграции по городам — число выбывших'
#  'Общие итоги миграции по городам — миграционный прирост'
#  'Общие итоги миграции по районам Крайнего Севера и местностям, приравненных к ним — число прибывших'
#  'Общие итоги миграции по районам Крайнего Севера и местностям, приравненных к ним — число выбывших'
#  'Общие итоги миграции по районам Крайнего Севера и местностям, приравненных к ним — миграционный прирост'
#  'Миграция по полу и возрасту в районах Крайнего Севера и местностях, приравненных к ним — число прибывших'
#  'Миграция по полу и возрасту в районах Крайнего Севера и местностях, приравненных к ним — число выбывших'
#  'Миграция по полу и возрасту в районах Крайнего Севера и местностях, приравненных к ним — миграционный прирост'
#  'Миграция по видам и срокам регистрации — число прибывших'
#  'Миграция по видам и срокам регистрации — число выбывших'
#  'Миграция по видам и срокам регистрации — миграционный прирост']

# %%
data_out = data_migration[(data_migration['indicator_name'] == 'Общие итоги миграции по субъектам — число выбывших') &
                         (data_migration['year'] >= 2011) & 
                          (data_migration['area_type'] == 'городское и сельское население')].copy()
display(data_out.head(20))
print(data_out.info())
# Out:
#             id            object_name  object_oktmo  object_okato  year  \
# 757424  757425         Алтайский край  1.000000e+09  1.000000e+09  2011
# 757425  757426         Алтайский край  1.000000e+09  1.000000e+09  2012
# 757426  757427         Алтайский край  1.000000e+09  1.000000e+09  2013
# 757427  757428         Алтайский край  1.000000e+09  1.000000e+09  2014
# 757428  757429         Алтайский край  1.000000e+09  1.000000e+09  2015
# 757429  757430         Алтайский край  1.000000e+09  1.000000e+09  2016
# 757430  757431         Алтайский край  1.000000e+09  1.000000e+09  2017
# 757431  757432         Алтайский край  1.000000e+09  1.000000e+09  2018
# 757432  757433         Алтайский край  1.000000e+09  1.000000e+09  2019
# 757447  757448       Амурская область  1.000000e+10  1.000000e+10  2011
# 757448  757449       Амурская область  1.000000e+10  1.000000e+10  2012
# 757449  757450       Амурская область  1.000000e+10  1.000000e+10  2013
# 757450  757451       Амурская область  1.000000e+10  1.000000e+10  2014
# 757451  757452       Амурская область  1.000000e+10  1.000000e+10  2015
# 757452  757453       Амурская область  1.000000e+10  1.000000e+10  2016
# 757453  757454       Амурская область  1.000000e+10  1.000000e+10  2017
# 757454  757455       Амурская область  1.000000e+10  1.000000e+10  2018
# 757455  757456       Амурская область  1.000000e+10  1.000000e+10  2019
# 757470  757471  Архангельская область  1.100000e+10  1.100000e+10  2011
# 757471  757472  Архангельская область  1.100000e+10  1.100000e+10  2012
#
#                                            indicator_name indicator_unit  \
# 757424  Общие итоги миграции по субъектам — число выбы...        человек
# 757425  Общие итоги миграции по субъектам — число выбы...        человек
# 757426  Общие итоги миграции по субъектам — число выбы...        человек
# 757427  Общие итоги миграции по субъектам — число выбы...        человек
# 757428  Общие итоги миграции по субъектам — число выбы...        человек
# 757429  Общие итоги миграции по субъектам — число выбы...        человек
# 757430  Общие итоги миграции по субъектам — число выбы...        человек
# 757431  Общие итоги миграции по субъектам — число выбы...        человек
# 757432  Общие итоги миграции по субъектам — число выбы...        человек
# 757447  Общие итоги миграции по субъектам — число выбы...        человек
# 757448  Общие итоги миграции по субъектам — число выбы...        человек
# 757449  Общие итоги миграции по субъектам — число выбы...        человек
# 757450  Общие итоги миграции по субъектам — число выбы...        человек
# 757451  Общие итоги миграции по субъектам — число выбы...        человек
# 757452  Общие итоги миграции по субъектам — число выбы...        человек
# 757453  Общие итоги миграции по субъектам — число выбы...        человек
# 757454  Общие итоги миграции по субъектам — число выбы...        человек
# 757455  Общие итоги миграции по субъектам — число выбы...        человек
# 757470  Общие итоги миграции по субъектам — число выбы...        человек
# 757471  Общие итоги миграции по субъектам — число выбы...        человек
#
#                              area_type age_group  sex migration_direction  \
# 757424  городское и сельское население       NaN  NaN        Вся миграция
# 757425  городское и сельское население       NaN  NaN        Вся миграция
# 757426  городское и сельское население       NaN  NaN        Вся миграция
# 757427  городское и сельское население       NaN  NaN        Вся миграция
# 757428  городское и сельское население       NaN  NaN        Вся миграция
# 757429  городское и сельское население       NaN  NaN        Вся миграция
# 757430  городское и сельское население       NaN  NaN        Вся миграция
# 757431  городское и сельское население       NaN  NaN        Вся миграция
# 757432  городское и сельское население       NaN  NaN        Вся миграция
# 757447  городское и сельское население       NaN  NaN        Вся миграция
# 757448  городское и сельское население       NaN  NaN        Вся миграция
# 757449  городское и сельское население       NaN  NaN        Вся миграция
# 757450  городское и сельское население       NaN  NaN        Вся миграция
# 757451  городское и сельское население       NaN  NaN        Вся миграция
# 757452  городское и сельское население       NaN  NaN        Вся миграция
# 757453  городское и сельское население       NaN  NaN        Вся миграция
# 757454  городское и сельское население       NaN  NaN        Вся миграция
# 757455  городское и сельское население       NaN  NaN        Вся миграция
# 757470  городское и сельское население       NaN  NaN        Вся миграция
# 757471  городское и сельское население       NaN  NaN        Вся миграция
#
#        country region territory_type registration_type citizenship  \
# 757424     NaN    NaN            NaN               NaN         NaN
# 757425     NaN    NaN            NaN               NaN         NaN
# 757426     NaN    NaN            NaN               NaN         NaN
# 757427     NaN    NaN            NaN               NaN         NaN
# 757428     NaN    NaN            NaN               NaN         NaN
# 757429     NaN    NaN            NaN               NaN         NaN
# 757430     NaN    NaN            NaN               NaN         NaN
# 757431     NaN    NaN            NaN               NaN         NaN
# 757432     NaN    NaN            NaN               NaN         NaN
# 757447     NaN    NaN            NaN               NaN         NaN
# 757448     NaN    NaN            NaN               NaN         NaN
# 757449     NaN    NaN            NaN               NaN         NaN
# 757450     NaN    NaN            NaN               NaN         NaN
# 757451     NaN    NaN            NaN               NaN         NaN
# 757452     NaN    NaN            NaN               NaN         NaN
# 757453     NaN    NaN            NaN               NaN         NaN
# 757454     NaN    NaN            NaN               NaN         NaN
# 757455     NaN    NaN            NaN               NaN         NaN
# 757470     NaN    NaN            NaN               NaN         NaN
# 757471     NaN    NaN            NaN               NaN         NaN
#
#         indicator_value  original_accuracy               methodology  notes
# 757424          80269.0                0.0  migration_2, migration_5    NaN
# 757425          93067.0                0.0  migration_2, migration_5    NaN
# 757426          96041.0                0.0  migration_2, migration_5    NaN
# 757427          87830.0                0.0  migration_2, migration_5    NaN
# 757428          85936.0                0.0  migration_2, migration_5    NaN
# 757429          82241.0                0.0  migration_2, migration_5    NaN
# 757430          80944.0                0.0  migration_2, migration_5    NaN
# 757431          86819.0                0.0  migration_2, migration_5    NaN
# 757432          83800.0                0.0  migration_2, migration_6    NaN
# 757447          28862.0                0.0  migration_2, migration_5    NaN
# 757448          29749.0                0.0  migration_2, migration_5    NaN
# 757449          31936.0                0.0  migration_2, migration_5    NaN
# 757450          31204.0                0.0  migration_2, migration_5    NaN
# 757451          33692.0                0.0  migration_2, migration_5    NaN
# 757452          32031.0                0.0  migration_2, migration_5    NaN
# 757453          31688.0                0.0  migration_2, migration_5    NaN
# 757454          32788.0                0.0  migration_2, migration_5    NaN
# 757455          29592.0                0.0  migration_2, migration_6    NaN
# 757470          38869.0                0.0  migration_2, migration_5    NaN
# 757471          46541.0                0.0  migration_2, migration_5    NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6856 entries, 757424 to 772471
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6856 non-null   int64
#  1   object_name          6856 non-null   object
#  2   object_oktmo         6056 non-null   float64
#  3   object_okato         6056 non-null   float64
#  4   year                 6856 non-null   int64
#  5   indicator_name       6856 non-null   object
#  6   indicator_unit       6856 non-null   object
#  7   area_type            6856 non-null   object
#  8   age_group            0 non-null      object
#  9   sex                  0 non-null      object
#  10  migration_direction  6856 non-null   object
#  11  country              0 non-null      object
#  12  region               0 non-null      object
#  13  territory_type       0 non-null      object
#  14  registration_type    0 non-null      object
#  15  citizenship          0 non-null      object
#  16  indicator_value      6852 non-null   float64
#  17  original_accuracy    6856 non-null   float64
#  18  methodology          6856 non-null   object
#  19  notes                0 non-null      float64
# dtypes: float64(5), int64(2), object(13)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# Сначала отделим `Общие итоги миграции по субъектам — число выбывших` и будем рассматривать всю подобную миграцию, то есть `городское и сельское население`:

# %%
data_out = data_migration[(data_migration['indicator_name'] == 'Общие итоги миграции по субъектам — число выбывших') &
                         (data_migration['year'] >= 2011) & 
                          (data_migration['area_type'] == 'городское и сельское население')].copy()
display(data_out.head(20))
print(data_out.info())
# Out:
#             id            object_name  object_oktmo  object_okato  year  \
# 757424  757425         Алтайский край  1.000000e+09  1.000000e+09  2011
# 757425  757426         Алтайский край  1.000000e+09  1.000000e+09  2012
# 757426  757427         Алтайский край  1.000000e+09  1.000000e+09  2013
# 757427  757428         Алтайский край  1.000000e+09  1.000000e+09  2014
# 757428  757429         Алтайский край  1.000000e+09  1.000000e+09  2015
# 757429  757430         Алтайский край  1.000000e+09  1.000000e+09  2016
# 757430  757431         Алтайский край  1.000000e+09  1.000000e+09  2017
# 757431  757432         Алтайский край  1.000000e+09  1.000000e+09  2018
# 757432  757433         Алтайский край  1.000000e+09  1.000000e+09  2019
# 757447  757448       Амурская область  1.000000e+10  1.000000e+10  2011
# 757448  757449       Амурская область  1.000000e+10  1.000000e+10  2012
# 757449  757450       Амурская область  1.000000e+10  1.000000e+10  2013
# 757450  757451       Амурская область  1.000000e+10  1.000000e+10  2014
# 757451  757452       Амурская область  1.000000e+10  1.000000e+10  2015
# 757452  757453       Амурская область  1.000000e+10  1.000000e+10  2016
# 757453  757454       Амурская область  1.000000e+10  1.000000e+10  2017
# 757454  757455       Амурская область  1.000000e+10  1.000000e+10  2018
# 757455  757456       Амурская область  1.000000e+10  1.000000e+10  2019
# 757470  757471  Архангельская область  1.100000e+10  1.100000e+10  2011
# 757471  757472  Архангельская область  1.100000e+10  1.100000e+10  2012
#
#                                            indicator_name indicator_unit  \
# 757424  Общие итоги миграции по субъектам — число выбы...        человек
# 757425  Общие итоги миграции по субъектам — число выбы...        человек
# 757426  Общие итоги миграции по субъектам — число выбы...        человек
# 757427  Общие итоги миграции по субъектам — число выбы...        человек
# 757428  Общие итоги миграции по субъектам — число выбы...        человек
# 757429  Общие итоги миграции по субъектам — число выбы...        человек
# 757430  Общие итоги миграции по субъектам — число выбы...        человек
# 757431  Общие итоги миграции по субъектам — число выбы...        человек
# 757432  Общие итоги миграции по субъектам — число выбы...        человек
# 757447  Общие итоги миграции по субъектам — число выбы...        человек
# 757448  Общие итоги миграции по субъектам — число выбы...        человек
# 757449  Общие итоги миграции по субъектам — число выбы...        человек
# 757450  Общие итоги миграции по субъектам — число выбы...        человек
# 757451  Общие итоги миграции по субъектам — число выбы...        человек
# 757452  Общие итоги миграции по субъектам — число выбы...        человек
# 757453  Общие итоги миграции по субъектам — число выбы...        человек
# 757454  Общие итоги миграции по субъектам — число выбы...        человек
# 757455  Общие итоги миграции по субъектам — число выбы...        человек
# 757470  Общие итоги миграции по субъектам — число выбы...        человек
# 757471  Общие итоги миграции по субъектам — число выбы...        человек
#
#                              area_type age_group  sex migration_direction  \
# 757424  городское и сельское население       NaN  NaN        Вся миграция
# 757425  городское и сельское население       NaN  NaN        Вся миграция
# 757426  городское и сельское население       NaN  NaN        Вся миграция
# 757427  городское и сельское население       NaN  NaN        Вся миграция
# 757428  городское и сельское население       NaN  NaN        Вся миграция
# 757429  городское и сельское население       NaN  NaN        Вся миграция
# 757430  городское и сельское население       NaN  NaN        Вся миграция
# 757431  городское и сельское население       NaN  NaN        Вся миграция
# 757432  городское и сельское население       NaN  NaN        Вся миграция
# 757447  городское и сельское население       NaN  NaN        Вся миграция
# 757448  городское и сельское население       NaN  NaN        Вся миграция
# 757449  городское и сельское население       NaN  NaN        Вся миграция
# 757450  городское и сельское население       NaN  NaN        Вся миграция
# 757451  городское и сельское население       NaN  NaN        Вся миграция
# 757452  городское и сельское население       NaN  NaN        Вся миграция
# 757453  городское и сельское население       NaN  NaN        Вся миграция
# 757454  городское и сельское население       NaN  NaN        Вся миграция
# 757455  городское и сельское население       NaN  NaN        Вся миграция
# 757470  городское и сельское население       NaN  NaN        Вся миграция
# 757471  городское и сельское население       NaN  NaN        Вся миграция
#
#        country region territory_type registration_type citizenship  \
# 757424     NaN    NaN            NaN               NaN         NaN
# 757425     NaN    NaN            NaN               NaN         NaN
# 757426     NaN    NaN            NaN               NaN         NaN
# 757427     NaN    NaN            NaN               NaN         NaN
# 757428     NaN    NaN            NaN               NaN         NaN
# 757429     NaN    NaN            NaN               NaN         NaN
# 757430     NaN    NaN            NaN               NaN         NaN
# 757431     NaN    NaN            NaN               NaN         NaN
# 757432     NaN    NaN            NaN               NaN         NaN
# 757447     NaN    NaN            NaN               NaN         NaN
# 757448     NaN    NaN            NaN               NaN         NaN
# 757449     NaN    NaN            NaN               NaN         NaN
# 757450     NaN    NaN            NaN               NaN         NaN
# 757451     NaN    NaN            NaN               NaN         NaN
# 757452     NaN    NaN            NaN               NaN         NaN
# 757453     NaN    NaN            NaN               NaN         NaN
# 757454     NaN    NaN            NaN               NaN         NaN
# 757455     NaN    NaN            NaN               NaN         NaN
# 757470     NaN    NaN            NaN               NaN         NaN
# 757471     NaN    NaN            NaN               NaN         NaN
#
#         indicator_value  original_accuracy               methodology  notes
# 757424          80269.0                0.0  migration_2, migration_5    NaN
# 757425          93067.0                0.0  migration_2, migration_5    NaN
# 757426          96041.0                0.0  migration_2, migration_5    NaN
# 757427          87830.0                0.0  migration_2, migration_5    NaN
# 757428          85936.0                0.0  migration_2, migration_5    NaN
# 757429          82241.0                0.0  migration_2, migration_5    NaN
# 757430          80944.0                0.0  migration_2, migration_5    NaN
# 757431          86819.0                0.0  migration_2, migration_5    NaN
# 757432          83800.0                0.0  migration_2, migration_6    NaN
# 757447          28862.0                0.0  migration_2, migration_5    NaN
# 757448          29749.0                0.0  migration_2, migration_5    NaN
# 757449          31936.0                0.0  migration_2, migration_5    NaN
# 757450          31204.0                0.0  migration_2, migration_5    NaN
# 757451          33692.0                0.0  migration_2, migration_5    NaN
# 757452          32031.0                0.0  migration_2, migration_5    NaN
# 757453          31688.0                0.0  migration_2, migration_5    NaN
# 757454          32788.0                0.0  migration_2, migration_5    NaN
# 757455          29592.0                0.0  migration_2, migration_6    NaN
# 757470          38869.0                0.0  migration_2, migration_5    NaN
# 757471          46541.0                0.0  migration_2, migration_5    NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6856 entries, 757424 to 772471
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6856 non-null   int64
#  1   object_name          6856 non-null   object
#  2   object_oktmo         6056 non-null   float64
#  3   object_okato         6056 non-null   float64
#  4   year                 6856 non-null   int64
#  5   indicator_name       6856 non-null   object
#  6   indicator_unit       6856 non-null   object
#  7   area_type            6856 non-null   object
#  8   age_group            0 non-null      object
#  9   sex                  0 non-null      object
#  10  migration_direction  6856 non-null   object
#  11  country              0 non-null      object
#  12  region               0 non-null      object
#  13  territory_type       0 non-null      object
#  14  registration_type    0 non-null      object
#  15  citizenship          0 non-null      object
#  16  indicator_value      6852 non-null   float64
#  17  original_accuracy    6856 non-null   float64
#  18  methodology          6856 non-null   object
#  19  notes                0 non-null      float64
# dtypes: float64(5), int64(2), object(13)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# У нас имеются 4 пропуска в `indicator_value` - посмотрим, где они, а также какие направления миграции у нас есть:

# %%
display(data_out[data_out['indicator_value'].isna()])
# Out:
#             id                 object_name  object_oktmo  object_okato  year  \
# 767055  767056                      Москва  4.500000e+10  4.500000e+10  2011
# 771925  771926   Ненецкий автономный округ  1.180000e+10  1.110000e+10  2014
# 772439  772440  Чукотский автономный округ  7.700000e+10  7.700000e+10  2014
# 772440  772441  Чукотский автономный округ  7.700000e+10  7.700000e+10  2015
#
#                                            indicator_name indicator_unit  \
# 767055  Общие итоги миграции по субъектам — число выбы...        человек
# 771925  Общие итоги миграции по субъектам — число выбы...        человек
# 772439  Общие итоги миграции по субъектам — число выбы...        человек
# 772440  Общие итоги миграции по субъектам — число выбы...        человек
#
#                              area_type age_group  sex  \
# 767055  городское и сельское население       NaN  NaN
# 771925  городское и сельское население       NaN  NaN
# 772439  городское и сельское население       NaN  NaN
# 772440  городское и сельское население       NaN  NaN
#
#                                       migration_direction country region  \
# 767055      Миграция в пределах России внутрирегиональная     NaN    NaN
# 771925  Миграция международная с зарубежными странами,...     NaN    NaN
# 772439  Миграция международная с зарубежными странами,...     NaN    NaN
# 772440  Миграция международная с зарубежными странами,...     NaN    NaN
#
#        territory_type registration_type citizenship  indicator_value  \
# 767055            NaN               NaN         NaN              NaN
# 771925            NaN               NaN         NaN              NaN
# 772439            NaN               NaN         NaN              NaN
# 772440            NaN               NaN         NaN              NaN
#
#         original_accuracy               methodology  notes
# 767055                0.0  migration_2, migration_5    NaN
# 771925                0.0  migration_2, migration_5    NaN
# 772439                0.0  migration_2, migration_5    NaN
# 772440                0.0  migration_2, migration_5    NaN

# %%
print(data_out['migration_direction'].unique())
# Out:
# ['Вся миграция' 'Внешняя для региона миграция'
#  'Миграция в пределах России' 'Миграция в пределах России межрегиональная'
#  'Миграция в пределах России внутрирегиональная' 'Миграция международная'
#  'Миграция международная со странами СНГ'
#  'Миграция международная с зарубежными странами, исключая страны СНГ']

# %% [markdown]
# Для оценки эмиграции нам нужны пункты `Миграция международная`, `Миграция международная со странами СНГ` и `Миграция международная с зарубежными странами, исключая страны СНГ` - внутререгиональный пропуск Москвы нас не очень-то интересует, но можно заполнить и его. Заполнять будем средним для групп "Регион - тип миграции":

# %%
moscow_set = data_out[(data_out['object_name'] == 'Москва') & 
                      (data_out['migration_direction'] == 'Миграция в пределах России внутрирегиональная')]
moscow_mean = np.floor(moscow_set['indicator_value'].mean())
data_out.loc[767055, 'indicator_value'] = moscow_mean

nen_set = data_out[(data_out['object_name'] == 'Ненецкий автономный округ') & 
                      (data_out['migration_direction'] == 'Миграция международная с зарубежными странами, исключая страны СНГ')]
nen_mean = np.floor(nen_set['indicator_value'].mean())
data_out.loc[771925, 'indicator_value'] = nen_mean

chu_set = data_out[(data_out['object_name'] == 'Чукотский автономный округ') & 
                      (data_out['migration_direction'] == 'Миграция международная с зарубежными странами, исключая страны СНГ')]
chu_mean = np.floor(chu_set['indicator_value'].mean())
data_out.loc[772439:772440, 'indicator_value'] = chu_mean

print(data_out.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6856 entries, 757424 to 772471
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6856 non-null   int64
#  1   object_name          6856 non-null   object
#  2   object_oktmo         6056 non-null   float64
#  3   object_okato         6056 non-null   float64
#  4   year                 6856 non-null   int64
#  5   indicator_name       6856 non-null   object
#  6   indicator_unit       6856 non-null   object
#  7   area_type            6856 non-null   object
#  8   age_group            0 non-null      object
#  9   sex                  0 non-null      object
#  10  migration_direction  6856 non-null   object
#  11  country              0 non-null      object
#  12  region               0 non-null      object
#  13  territory_type       0 non-null      object
#  14  registration_type    0 non-null      object
#  15  citizenship          0 non-null      object
#  16  indicator_value      6856 non-null   float64
#  17  original_accuracy    6856 non-null   float64
#  18  methodology          6856 non-null   object
#  19  notes                0 non-null      float64
# dtypes: float64(5), int64(2), object(13)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# Отлично, пропусков больше нет. Ради интереса можно посмотреть и топ-10 для всей миграции скопом:

# %%
data_out_all = data_out[data_out['migration_direction'] == 'Вся миграция'].copy()

top_out = pd.pivot_table(data_out_all, index='object_name', values='indicator_value', aggfunc='sum').sort_values(
    by='indicator_value', ascending=False)
top_out['indicator_value'] = top_out['indicator_value'].astype('int64')

top_out = top_out[(top_out.index.str.contains('федеральный округ') == False) & 
                      (top_out.index.str.contains('Федерация') == False)]
display(top_out.head(10))
tops_plot(top_out, 10, 'Вся миграция - число выбывших')
# Out:
#                          indicator_value
# object_name
# Московская область               1986182
# Санкт-Петербург                  1592248
# Москва                           1552985
# Тюменская область                1518297
# Республика Башкортостан          1320972
# Краснодарский край               1296435
# Свердловская область             1022236
# Красноярский край                1015113
# Ростовская область                913295
# Челябинская область               826287

# %% [markdown]
# Топ-3 здесь, конечно, очень интересен, учитывая, что рассматривается число выбывших - однако это вся миграция скопом, включая временную. Трактовать эти числа тяжеловато - перейдём к эмиграции:

# %% [markdown]
# ### <center>Основные источники эмиграции</center>

# %% [markdown]
# Рассмотрим отдельно эмиграцию в страны СНГ; в другие страны, кроме СНГ, и эмиграцию общую - начнём с СНГ:

# %%
#выделяем данные
data_out_sng = data_out[
    data_out['migration_direction'] == 'Миграция международная со странами СНГ'].copy()

#суммируем за период 2011-2019 и сортируем по убыванию
top_out_sng = pd.pivot_table(
    data_out_sng, index='object_name', values='indicator_value', aggfunc='sum').sort_values(
    by='indicator_value', ascending=False)
top_out_sng['indicator_value'] = top_out_sng['indicator_value'].astype('int64')

#убираем фед. округа и общую сумму
top_out_sng = top_out_sng[
    (top_out_sng.index.str.contains('федеральный округ') == False) & 
    (top_out_sng.index.str.contains('Федерация') == False)]
display(top_out_sng.head(10))
# Out:
#                        indicator_value
# object_name
# Санкт-Петербург                 226001
# Тюменская область               112953
# Москва                          106230
# Московская область              103934
# Ленинградская область            75568
# Тамбовская область               65570
# Калужская область                63964
# Новосибирская область            62364
# Воронежская область              58302
# Краснодарский край               58140

# %%
tops_plot(top_out_sng, 10, 'Mиграция в страны СНГ')

# %% [markdown]
# Здесь Санкт-Петербург побеждает с очень заметным отрывом - то есть в страны СНГ в значительном количестве переехали люди из СПб. Далее неожиданно идёт Тюменская область и на третьем месте - Москва. Посмотрим эмиграцию в страны, не являющиеся странами СНГ:

# %%
#выделяем данные
data_out_not_sng = data_out[
    data_out['migration_direction'] == 'Миграция международная с зарубежными странами, исключая страны СНГ'].copy()

#суммируем за период 2011-2019 и сортируем по убыванию
top_out_not_sng = pd.pivot_table(
    data_out_not_sng, index='object_name', values='indicator_value', aggfunc='sum').sort_values(
    by='indicator_value', ascending=False)
top_out_not_sng['indicator_value'] = top_out_not_sng['indicator_value'].astype('int64')

#убираем фед. округа и общую сумму
top_out_not_sng = top_out_not_sng[
    (top_out_not_sng.index.str.contains('федеральный округ') == False) & 
    (top_out_not_sng.index.str.contains('Федерация') == False)]
display(top_out_not_sng.head(10))
# Out:
#                        indicator_value
# object_name
# Москва                           34717
# Хабаровский край                 32488
# Приморский край                  31704
# Санкт-Петербург                  30079
# Тамбовская область               18097
# Краснодарский край               12542
# Астраханская область             12341
# Смоленская область               12048
# Новосибирская область            11803
# Воронежская область              11151

# %%
tops_plot(top_out_not_sng, 10, 'Mиграция в другие страны, исключая СНГ')

# %% [markdown]
# А вот здесь побеждает Москва - СПб на почётном четвёртом месте. На втором и третьем местах - Хабаровский и Приморский край, что, конечно, крайне любопытно. Перейдём к общей эмиграции - и здесь для начала проверим, сходится ли сумма выделенных нами данных с графой `Миграция международная`:

# %%
top_out_international = (top_out_not_sng + top_out_sng).sort_values(
    by='indicator_value', ascending=False) 
display(top_out_international.head(10))
# Out:
#                        indicator_value
# object_name
# Санкт-Петербург                 256080
# Москва                          140947
# Тюменская область               120911
# Московская область              114428
# Тамбовская область               83667
# Ленинградская область            81777
# Новосибирская область            74167
# Приморский край                  72162
# Краснодарский край               70682
# Воронежская область              69453

# %%
data_test = data_out[
    data_out['migration_direction'] == 'Миграция международная'].copy()

top_test = pd.pivot_table(
    data_test, index='object_name', values='indicator_value', aggfunc='sum').sort_values(
    by='indicator_value', ascending=False)

top_test = top_test[
    (top_test.index.str.contains('федеральный округ') == False) & 
    (top_test.index.str.contains('Федерация') == False)]
display(top_test.head(10))
# Out:
#                        indicator_value
# object_name
# Санкт-Петербург               256080.0
# Москва                        140947.0
# Тюменская область             120911.0
# Московская область            114428.0
# Тамбовская область             83667.0
# Ленинградская область          81777.0
# Новосибирская область          74167.0
# Приморский край                72162.0
# Краснодарский край             70682.0
# Воронежская область            69453.0

# %% [markdown]
# Да, сходится, то есть вопросов к себе у нас нет :) Строим график:

# %%
tops_plot(top_out_international, 15, 'Mиграция в другие страны')

# %% [markdown]
# Итого Санкт-Петербург за счёт очень высокой эмиграции в страны СНГ оказывается на первом месте. На втором месте по общей эмиграции Москва, а Московская область - на 4-ом, между ними неожиданно затесалась область Тюменская. Посмотрим общее количество эмигрировавших:

# %%
print(sum(top_out_international['indicator_value']))
# Out:
# 2683312

# %% [markdown]
# Свыше 2.5 млн человек. Сколько из них вернулись - неизвестно.

# %% [markdown]
# ### <center>Санкт-Петербург и Москва</center>

# %% [markdown]
# Для начала рассмотрим всю эмиграцию из СПб и Мск с 2000 года:

# %%
#выделяем нужные данные
data_out2000 = data_migration[(data_migration['indicator_name'] == 'Общие итоги миграции по субъектам — число выбывших') &
                         (data_migration['year'] >= 2000) & 
                          (data_migration['area_type'] == 'городское и сельское население') & 
                              (data_migration['migration_direction'] == 'Миграция международная')].copy()

#оставляем только те колонки, которые нам нужны
data_temp = data_out2000[['object_name', 'year', 'indicator_value']]

#отделяем СПб и Мск
spb_out = data_temp[data_temp['object_name'] == 'Санкт-Петербург'].copy()
moscow_out = data_temp[data_temp['object_name'] == 'Москва'].copy()
spb_out['indicator_value'] = spb_out['indicator_value'].astype('int64')
moscow_out['indicator_value'] = moscow_out['indicator_value'].astype('int64')

display(spb_out)
display(moscow_out)
# Out:
#             object_name  year  indicator_value
# 770081  Санкт-Петербург  2000             4872
# 770082  Санкт-Петербург  2001             3660
# 770083  Санкт-Петербург  2002             2817
# 770084  Санкт-Петербург  2003             1939
# 770085  Санкт-Петербург  2004             1758
# 770086  Санкт-Петербург  2005             1779
# 770087  Санкт-Петербург  2006              906
# 770088  Санкт-Петербург  2007              785
# 770089  Санкт-Петербург  2008              883
# 770090  Санкт-Петербург  2009              649
# 770091  Санкт-Петербург  2010              676
# 770092  Санкт-Петербург  2011              851
# 770093  Санкт-Петербург  2012             9602
# 770094  Санкт-Петербург  2013            25204
# 770095  Санкт-Петербург  2014            62941
# 770096  Санкт-Петербург  2015            57725
# 770097  Санкт-Петербург  2016            21440
# 770098  Санкт-Петербург  2017            17650
# 770099  Санкт-Петербург  2018            30170
# 770100  Санкт-Петербург  2019            30497
#        object_name  year  indicator_value
# 769271      Москва  2000             6824
# 769272      Москва  2001             6700
# 769273      Москва  2002             5448
# 769274      Москва  2003             4737
# 769275      Москва  2004             2940
# 769276      Москва  2005             3048
# 769277      Москва  2006             2772
# 769278      Москва  2007             2814
# 769279      Москва  2008             2919
# 769280      Москва  2009             3016
# 769281      Москва  2010             3303
# 769282      Москва  2011             4002
# 769283      Москва  2012             5252
# 769284      Москва  2013             8028
# 769285      Москва  2014            12705
# 769286      Москва  2015            16917
# 769287      Москва  2016            18892
# 769288      Москва  2017            22405
# 769289      Москва  2018            26155
# 769290      Москва  2019            26591

# %%
plt.figure(figsize=(14, 8))
plt.plot(spb_out['year'], spb_out['indicator_value'], color='red', marker='o', label='СПб')
plt.plot(moscow_out['year'], moscow_out['indicator_value'], color='blue', marker='o', label='Москва')
plt.title('Уехавшие', fontsize=18)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('год', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('международная миграция', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(loc='upper right', fontsize=16)
plt.show()

# %% [markdown]
# Результаты, признаться, интересны - вернёмся к нашему диапазону 2011-2019:

# %%
plt.figure(figsize=(14, 8))
plt.plot(spb_out['year'], spb_out['indicator_value'], color='red', marker='o', label='СПб')
plt.plot(moscow_out['year'], moscow_out['indicator_value'], color='blue', marker='o', label='Москва')
plt.title('Уехавшие', fontsize=18)
plt.xlim(2011, 2019)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('год', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('международная миграция', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(loc='upper right', fontsize=16)
plt.show()

# %% [markdown]
# Санкт-Петербург похож на город очень ярко выраженной политической эмиграции со своим скачком в 2014. Интересно, что Москва же просто стабильно растёт с 2012 - посмотрим, что у нас будет в соответствующих областях:

# %% [markdown]
# ### <center>Ленинградская и Московская области</center>

# %% [markdown]
# Также сначала посмотрим период с 2000:

# %%
lenobl_out = data_temp[data_temp['object_name'] == 'Ленинградская область'].copy()
mosobl_out = data_temp[data_temp['object_name'] == 'Московская область'].copy()
lenobl_out['indicator_value'] = lenobl_out['indicator_value'].astype('int64')
mosobl_out['indicator_value'] = mosobl_out['indicator_value'].astype('int64')
display(lenobl_out)
display(mosobl_out)

plt.figure(figsize=(14, 8))
plt.plot(lenobl_out['year'], lenobl_out['indicator_value'], color='red', marker='o', label='Лен. обл')
plt.plot(mosobl_out['year'], mosobl_out['indicator_value'], color='blue', marker='o', label='Моск. обл')
plt.title('Уехавшие из областей', fontsize=18)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('год', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('международная миграция', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(loc='lower right', fontsize=16)
plt.show()
# Out:
#                   object_name  year  indicator_value
# 769202  Ленинградская область  2000             1734
# 769203  Ленинградская область  2001             1312
# 769204  Ленинградская область  2002             1217
# 769205  Ленинградская область  2003             1090
# 769206  Ленинградская область  2004              853
# 769207  Ленинградская область  2005              729
# 769208  Ленинградская область  2006              808
# 769209  Ленинградская область  2007              608
# 769210  Ленинградская область  2008              549
# 769211  Ленинградская область  2009              467
# 769212  Ленинградская область  2010              430
# 769213  Ленинградская область  2011              400
# 769214  Ленинградская область  2012             3200
# 769215  Ленинградская область  2013            13005
# 769216  Ленинградская область  2014            16905
# 769217  Ленинградская область  2015            15730
# 769218  Ленинградская область  2016             6767
# 769219  Ленинградская область  2017             7633
# 769220  Ленинградская область  2018            10155
# 769221  Ленинградская область  2019             7982
#                object_name  year  indicator_value
# 769294  Московская область  2000             2614
# 769295  Московская область  2001             1906
# 769296  Московская область  2002             1889
# 769297  Московская область  2003             1568
# 769298  Московская область  2004             1453
# 769299  Московская область  2005             1260
# 769300  Московская область  2006             1165
# 769301  Московская область  2007             1121
# 769302  Московская область  2008             1248
# 769303  Московская область  2009             1023
# 769304  Московская область  2010             1187
# 769305  Московская область  2011             1631
# 769306  Московская область  2012             6687
# 769307  Московская область  2013             9008
# 769308  Московская область  2014            13002
# 769309  Московская область  2015            15375
# 769310  Московская область  2016            14858
# 769311  Московская область  2017            16277
# 769312  Московская область  2018            19072
# 769313  Московская область  2019            18518

# %% [markdown]
# И здесь мы видим, что характер сохраняется - рассмотрим промежуток 2011-2019

# %%
plt.figure(figsize=(14, 8))
plt.plot(lenobl_out['year'], lenobl_out['indicator_value'], color='red', marker='o', label='Лен. обл')
plt.plot(mosobl_out['year'], mosobl_out['indicator_value'], color='blue', marker='o', label='Моск. обл')
plt.title('Уехавшие из областей', fontsize=18)
plt.xlim(2011, 2019)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('год', fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('международная миграция', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(loc='lower right', fontsize=16)
plt.show()

# %% [markdown]
# Области ведут себя соответственно городам: у Лен. области, как и у СПб, ярко выражен максимум в 2014, а Московская область стабильно растёт, как Москва. Однако стоит отметить, что Московская область начиная с 2016 года обгоняет Ленинградскую область, в то время как показатели Москвы ниже показателей Санкт-Петербурга во все года, кроме 2017 (если рассматривать отрезок 2011-2019).

# %% [markdown]
# Здесь стоит вспомнить о том, что Санкт-Петербург - победитель по миграции в страны СНГ. Рискну предположить, что различие между Петербургом и Москвой связано в том числе с более высоким уровнем жизни в Москве, отказаться от которого людям тяжелее - в то время как жители Санкт-Петербурга в этом отношении более легки на подъём, и основные скачки питерской эмиграции - 2012 год (с `851` до `9602`) и 2014 (максимум в `62941`).
#
# Стоит однако отметить, что Санкт-Петербург по эмиграции стал опережать Москву только в 2012 году, а в период 2000-2011 всё было наоборот, Москва СПб опережала - но в 2012 году это положение дел изменилось, причём резко.

# %% [markdown]
# ## <center>Выводы</center>

# %% [markdown]
# В Санкт-Петербург за период 2011-2019 переехало в ~1.5 раза больше людей, чем в Москву - предполагаю, что это связано с более доступными ценами на жильё. Однако если смотреть на переезды в целом, то на первом месте окажется Московская область - Москва находится на 10-м, а Санкт-Петербург - на 4-м. 2-е и 3-е занимают Башкирия и Тюменская область соответственно - почему так, сказать затрудняюсь, эта тема требует отдельного исследования.
#
# В вопросе эмиграции в другие страны Санкт-Петербург и Москва лидируют: занимают 1-е и 2-е место соответственно, причём Санкт-Петербург побеждает с заметным отрывом (`256080` против `140947`). Эмиграция из Санкт-Петербурга носит отчётливый политический характер: её максимум (`62941`) приходится на 2014 год, а первичный резкий скачок (с `851` до `9602`) - на 2012. Москва же начиная с 2012 просто стабильно растёт - и здесь стоит отметить два момента:
# + **до** 2012 - а точнее в период **2000-2011** - Москва опережала Санкт-Петербург по миграции в другие страны; картина резко изменилась именно в **2012**: Санкт-Петербург начал опережать Москву, причём с очень заметным отрывом (исключение составляет 2017 год);
# + Санкт-Петербург является безусловным лидером по эмиграции в страны СНГ; по эмиграции в страны СНГ Москва находится только на 3-м месте - и на 1-м месте по эмиграции в страны, не являющиеся странами СНГ. Рискну предположить, что это связано с более высоким уровнем жизни в Москве, отказаться от которого людям тяжелее.
#
# Эмиграция в Московской и Ленинградской областях по характеру совпадает с городами - однако Московская область по количеству эмигрировавших стабильно опережает Ленинградскую, начиная с 2016 года. В то время как Москва от Санкт-Петербурга отстаёт на всём отрезке 2011-2019, исключая 2017 год.
